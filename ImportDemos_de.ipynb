# %%
# %pip install dbdemos

# %%
import dbdemos
dbdemos.list_demos()

# %%
dbdemos.install('lakehouse-retail-c360', catalog='mfg_central', schema='c360')

# %%
#dbdemos.install('pipeline-bike', catalog='mfg_central', schema='pipeline_bike')
dbdemos.install('lakehouse-retail-c360', catalog='mfg_central', schema='c360)
